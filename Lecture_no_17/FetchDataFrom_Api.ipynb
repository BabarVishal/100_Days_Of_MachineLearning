# %%
import pandas as pd;
import requests;

# %%
res = requests.get('https://jsonplaceholder.typicode.com/posts')

# %%
df = pd.DataFrame(res.json())[['id', 'title', 'body']]

# %%
df.head()
# Out:
#    id                                              title  \
# 0   1  sunt aut facere repellat provident occaecati e...
# 1   2                                       qui est esse
# 2   3  ea molestias quasi exercitationem repellat qui...
# 3   4                               eum et est occaecati
# 4   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
df.shape
# Out:
# (100, 3)

# %%
df.to_csv('data.csv')

# %%
load = pd.read_csv('data.csv')
load
# Out:
#     Unnamed: 0   id                                              title  \
# 0            0    1  sunt aut facere repellat provident occaecati e...
# 1            1    2                                       qui est esse
# 2            2    3  ea molestias quasi exercitationem repellat qui...
# 3            3    4                               eum et est occaecati
# 4            4    5                                 nesciunt quas odio
# ..         ...  ...                                                ...
# 95          95   96  quaerat velit veniam amet cupiditate aut numqu...
# 96          96   97         quas fugiat ut perspiciatis vero provident
# 97          97   98                        laboriosam dolor voluptates
# 98          98   99  temporibus sit alias delectus eligendi possimu...
# 99          99  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# ...
