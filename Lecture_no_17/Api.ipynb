# %%
import pandas as pd;
import requests

# %%
res = requests.get('https://jsonplaceholder.typicode.com/posts')

# %%
df = pd.DataFrame(res.json())[['id', 'title', 'body']].set_index('id')

# %%
df
# Out:
#                                                  title  \
# id
# 1    sunt aut facere repellat provident occaecati e...
# 2                                         qui est esse
# 3    ea molestias quasi exercitationem repellat qui...
# 4                                 eum et est occaecati
# 5                                   nesciunt quas odio
# ..                                                 ...
# 96   quaerat velit veniam amet cupiditate aut numqu...
# 97          quas fugiat ut perspiciatis vero provident
# 98                         laboriosam dolor voluptates
# 99   temporibus sit alias delectus eligendi possimu...
# 100              at nam consequatur ea labore ea harum
#
#                                                   body
# id
# 1    quia et suscipit\nsuscipit recusandae consequu...
# 2    est rerum tempore vitae\nsequi sint nihil repr...
# 3    et iusto sed quo iure\nvoluptatem occaecati om...
# 4    ullam et saepe reiciendis voluptatem adipisci\...
# ...
