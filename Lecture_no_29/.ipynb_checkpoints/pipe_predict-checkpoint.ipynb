# %%
import pickle
import numpy as np
import pandas as pd

pipe = pickle.load(open('pipe.pkl', 'rb'))

# Create DataFrame with the same column names used during training
columns = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

rest_input2 = pd.DataFrame([[2, 'male', 31.2, 0, 0, 10.5, 'S']], columns=columns)

pipe.predict(rest_input2)
# Out:
# array([1])
