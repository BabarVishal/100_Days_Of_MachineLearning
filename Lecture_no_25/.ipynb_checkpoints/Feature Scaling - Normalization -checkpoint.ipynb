# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
import seaborn as sns;

# %%
df = pd.read_csv('wine_like_data.csv')
df.head()
# Out:
#    Class label  Alcohol  Malic acid
# 0            3    11.32        4.41
# 1            1    13.10        4.13
# 2            3    12.64        4.06
# 3            3    14.93        1.87
# 4            1    11.45        0.86

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.isnull().sum()
# Out:
# Class label    0
# Alcohol        0
# Malic acid     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Class label  Alcohol  Malic acid
# 0            3    11.32        4.41
# 1            1    13.10        4.13
# 2            3    12.64        4.06
# 3            3    14.93        1.87
# 4            1    11.45        0.86

# %%
color = {1: 'red', 2: 'green', 3: 'blue'}

sns.scatterplot(
    x=df['Alcohol'],
    y=df['Malic acid'],
    hue=df['Class label'],
    palette=color
)

plt.xlabel("Alcohol")
plt.ylabel("Malic acid")
plt.title("Alcohol vs Malic Acid by Class")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    df.drop('Class label', axis=1),
    df['Class label'],
    test_size=0.3,
    random_state=1
)
x_train.shape, x_test.shape
# Out:
# ((700, 2), (300, 2))

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
scale.fit(x_train)

x_train_scale = scale.transform(x_train)
x_test_scale = scale.transform(x_test)

x_train_scale = pd.DataFrame(x_train_scale, columns=x_train.columns)
x_test_scale = pd.DataFrame(x_test_scale, columns=x_test.columns)

# %%
np.round(x_train.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    700.0       700.0
# mean      13.0         2.8
# std        1.2         1.3
# min       11.0         0.5
# 25%       11.9         1.7
# 50%       13.0         2.7
# 75%       14.0         3.9
# max       15.0         5.0

# %%
np.round(x_train_scale.describe())
# Out:
#        Alcohol  Malic acid
# count    700.0       700.0
# mean       0.0         1.0
# std        0.0         0.0
# min        0.0         0.0
# 25%        0.0         0.0
# 50%        0.0         0.0
# 75%        1.0         1.0
# max        1.0         1.0

# %%
fig, (a, b) = plt.subplots(ncols=2, figsize=(12, 5))

a.scatter(x_train['Alcohol'], x_train['Malic acid'], c = y_train)
a.set_title('Before Scaling')

b.scatter(x_train_scale['Alcohol'], x_train_scale['Malic acid'], c = y_train)
b.set_title('Before Scaling')
# Out:
# Text(0.5, 1.0, 'Before Scaling')
