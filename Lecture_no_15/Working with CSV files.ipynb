# %%
import pandas as pd;

# %%
# 1. Import CSV File
data = pd.read_csv('customer_data_150.csv')
data.head()
# Out:
#    Customer_ID  Age  Gender Item_Purchased     Category  Purchase_Amount_USD  \
# 0            1   32   Other          Shoes     Footwear               390.95
# 1            2   47  Female     Smartwatch  Electronics                 5.39
# 2            3   20    Male           Eggs    Groceries               305.73
# 3            4   25   Other          Boots     Footwear                90.82
# 4            5   51  Female         Laptop  Electronics               447.94
#
#     Location Size  Color Season  Review_Rating Subscription_Status  \
# 0  Hyderabad    M  Black  Rainy            1.2            Inactive
# 1  Bangalore    -    Red    All            3.4              Active
# 2  Hyderabad    S   Blue    All            4.8            Inactive
# 3     Mumbai   XL   Blue    All            4.0            Inactive
# 4  Bangalore    S  Green    All            4.0              Active
#
#   Shipping_Type  Discount_Applied Promo_Code_Used  Previous_Purchases  \
# ...

# %%
# 2. Open Csv file using URL

# %%
# import requests
# from io import StringIO
# url = ""
# headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
# req = requests.get(url, headers=headers)
# data = StringIO(req.text)
# pd.read_csv(data)

# %%
# 3. Import TSV file 
df1 = pd.read_csv('Employee Dataset - TSV.txt', sep='\t')
df1.head()
# pd.read_csv('Employee Dataset - TSV.txt', sep='\t', names=[Employee Name, Age, ect...])
# Out:
#   Employee Name  Age Last Working Day            Department      Education  \
# 0        Jitesh   41       31-12-9999              Training        Masters
# 1        Sanjit   49       31-12-9999                 Sales        Masters
# 2          John   37       31-12-9999                   R&D      Doctorate
# 3        Sandra   33       31-12-9999  Software Development  Undergraduate
# 4         Madhu   27       31-12-9999                   R&D        Masters
#
#    Gender Marital Status  Monthly Income  Years of Experience  \
# 0    Male         Single            5993                    8
# 1    Male        Married            5130                    1
# 2    Male         Single            2090                    6
# 3  Female        Married            2909                    1
# 4    Male        Married            3468                    9
#
#    Percent Salary Hike  Performance Rating
# 0                   11                   3
# 1                   23                   4
# ...

# %%
# 4. Index_col parameter....
df = pd.read_csv('customer_data_150.csv', index_col='Customer_ID')
df.head()
# Out:
#              Age  Gender Item_Purchased     Category  Purchase_Amount_USD  \
# Customer_ID
# 1             32   Other          Shoes     Footwear               390.95
# 2             47  Female     Smartwatch  Electronics                 5.39
# 3             20    Male           Eggs    Groceries               305.73
# 4             25   Other          Boots     Footwear                90.82
# 5             51  Female         Laptop  Electronics               447.94
#
#               Location Size  Color Season  Review_Rating Subscription_Status  \
# Customer_ID
# 1            Hyderabad    M  Black  Rainy            1.2            Inactive
# 2            Bangalore    -    Red    All            3.4              Active
# 3            Hyderabad    S   Blue    All            4.8            Inactive
# 4               Mumbai   XL   Blue    All            4.0            Inactive
# 5            Bangalore    S  Green    All            4.0              Active
#
# ...

# %%
# 5. Header Parameter 
df = pd.read_csv('customer_data_150.csv', header=1) # If the Header was in fisth line

# %%
# 6. use_cols parameter
df6 = pd.read_csv('customer_data_150.csv', usecols=['Customer_ID', 'Age'])
df6.head()
# Out:
#    Customer_ID  Age
# 0            1   32
# 1            2   47
# 2            3   20
# 3            4   25
# 4            5   51

# %%
# 7. Squeeze parameters
# df7 = pd.read_csv('customer_data_150.csv', usecols=['age'], squeeze=True)
# df7

# %%
# 8. Skiprows/nrows parameterab
pd.read_csv('customer_data_150.csv', skiprows=[1,2], nrows=100)
# Out:
#     Customer_ID  Age  Gender Item_Purchased     Category  Purchase_Amount_USD  \
# 0             3   20    Male           Eggs    Groceries               305.73
# 1             4   25   Other          Boots     Footwear                90.82
# 2             5   51  Female         Laptop  Electronics               447.94
# 3             6   42   Other          Watch  Accessories               214.58
# 4             7   45   Other         Mobile  Electronics               425.77
# ..          ...  ...     ...            ...          ...                  ...
# 95           98   56   Other           Belt  Accessories                 5.55
# 96           99   41    Male     Smartwatch  Electronics               391.02
# 97          100   34  Female          Boots     Footwear               355.74
# 98          101   29   Other          Shoes     Footwear                37.48
# 99          102   56   Other          Watch  Accessories               398.43
#
# ...

# %%
# 9. Encoding parameter..
 #pd.read_csv('customer_data_150.csv', encoding='')

# %%
# 10. Skip bad lines.. 
df10 = pd.read_csv('customer_data_150.csv', error_bad_lines=False)

# %%
# 11.. Dtype
df11 = pd.read_csv('customer_data_150.csv', dtype={'Customer_ID':int}).info()
df11
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_ID             150 non-null    int64
#  1   Age                     150 non-null    int64
#  2   Gender                  150 non-null    object
#  3   Item_Purchased          150 non-null    object
#  4   Category                150 non-null    object
#  5   Purchase_Amount_USD     150 non-null    float64
#  6   Location                150 non-null    object
#  7   Size                    150 non-null    object
#  8   Color                   150 non-null    object
#  9   Season                  150 non-null    object
#  10  Review_Rating           150 non-null    float64
#  11  Subscription_Status     150 non-null    object
#  12  Shipping_Type           150 non-null    object
#  13  Discount_Applied        150 non-null    int64
# ...

# %%
# 12. Handling Dates
pd.read_csv('customer_data_150.csv', parse_dates=['Date'])

# %%
# # 13. Convertors
def rename(name):
   if name == 'Hyderabad':
       return 'HYD'
   else:
       return name

# %%
rename('Hyderabad')
# Out:
# 'HYD'

# %%
pd.read_csv('customer_data_150.csv', converters={'Location': rename})
# Out:
#      Customer_ID  Age  Gender Item_Purchased     Category  \
# 0              1   32   Other          Shoes     Footwear
# 1              2   47  Female     Smartwatch  Electronics
# 2              3   20    Male           Eggs    Groceries
# 3              4   25   Other          Boots     Footwear
# 4              5   51  Female         Laptop  Electronics
# ..           ...  ...     ...            ...          ...
# 145          146   54   Other     Headphones  Electronics
# 146          147   44    Male         Laptop  Electronics
# 147          148   54    Male           Belt  Accessories
# 148          149   46    Male           Rice    Groceries
# 149          150   57    Male          Jeans     Clothing
#
#      Purchase_Amount_USD   Location Size  Color  Season  Review_Rating  \
# 0                 390.95        HYD    M  Black   Rainy            1.2
# 1                   5.39  Bangalore    -    Red     All            3.4
# ...
