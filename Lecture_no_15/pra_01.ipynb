# %%
import pandas as pd;

# %%
data = pd.read_csv('customer_data_150.csv', index_col='Customer_ID')
data.head()
# Out:
#              Age  Gender Item_Purchased     Category  Purchase_Amount_USD  \
# Customer_ID
# 1             32   Other          Shoes     Footwear               390.95
# 2             47  Female     Smartwatch  Electronics                 5.39
# 3             20    Male           Eggs    Groceries               305.73
# 4             25   Other          Boots     Footwear                90.82
# 5             51  Female         Laptop  Electronics               447.94
#
#               Location Size  Color Season  Review_Rating Subscription_Status  \
# Customer_ID
# 1            Hyderabad    M  Black  Rainy            1.2            Inactive
# 2            Bangalore    -    Red    All            3.4              Active
# 3            Hyderabad    S   Blue    All            4.8            Inactive
# 4               Mumbai   XL   Blue    All            4.0            Inactive
# 5            Bangalore    S  Green    All            4.0              Active
#
# ...

# %%
data2 = pd.read_csv('customer_data_150.csv', usecols=['Customer_ID', 'Age'])
data2.head()
# Out:
#    Customer_ID  Age
# 0            1   32
# 1            2   47
# 2            3   20
# 3            4   25
# 4            5   51

# %%
data3 = pd.read_csv('customer_data_150.csv', skiprows=[1,5], nrows=50)
data3
# Out:
#     Customer_ID  Age  Gender Item_Purchased     Category  Purchase_Amount_USD  \
# 0             2   47  Female     Smartwatch  Electronics                 5.39
# 1             3   20    Male           Eggs    Groceries               305.73
# 2             4   25   Other          Boots     Footwear                90.82
# 3             6   42   Other          Watch  Accessories               214.58
# 4             7   45   Other         Mobile  Electronics               425.77
# 5             8   52    Male           Rice    Groceries               486.00
# 6             9   30   Other     Smartwatch  Electronics                20.56
# 7            10   49   Other          Shoes     Footwear               148.43
# 8            11   45    Male           Eggs    Groceries               162.41
# 9            12   54    Male          Jeans     Clothing                64.33
# 10           13   34   Other        T-Shirt     Clothing               306.73
# ...

# %%
data4 = pd.read_csv('customer_data_150.csv', dtype={'Customer_ID':int})
