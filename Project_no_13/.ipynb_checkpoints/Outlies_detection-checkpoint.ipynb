# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('titanic_50000.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass         Name     Sex        Age  SibSp  \
# 0            1         0       1  Passenger_1    male  28.505531      4
# 1            2         1       1  Passenger_2  female  16.290422      0
# 2            3         0       3  Passenger_3    male  54.239256      3
# 3            4         0       3  Passenger_4  female  25.934960      1
# 4            5         0       3  Passenger_5  female  44.024119      2
#
#    Parch     Ticket       Fare Cabin Embarked
# 0      1  TCKT84588  21.803954   NaN        S
# 1      3  TCKT87215  25.140471   NaN        S
# 2      4  TCKT56430  62.139033   NaN        S
# 3      2  TCKT97536  70.722917  C187        Q
# 4      3  TCKT56341  11.959749   NaN        S

# %%
df.shape
# Out:
# (50000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  50000 non-null  int64
#  1   Survived     50000 non-null  int64
#  2   Pclass       50000 non-null  int64
#  3   Name         50000 non-null  object
#  4   Sex          50000 non-null  object
#  5   Age          50000 non-null  float64
#  6   SibSp        50000 non-null  int64
#  7   Parch        50000 non-null  int64
#  8   Ticket       50000 non-null  object
#  9   Fare         50000 non-null  float64
#  10  Cabin        15004 non-null  object
#  11  Embarked     50000 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 4.6+ MB

# %%
df.describe()
# Out:
#         PassengerId      Survived        Pclass           Age         SibSp  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean   25000.500000      0.499080      2.299300     30.094317      2.485500
# std    14433.901067      0.500004      0.780161     13.788365      1.708581
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%    12500.750000      0.000000      2.000000     20.589989      1.000000
# 50%    25000.500000      0.000000      2.000000     30.004980      2.000000
# 75%    37500.250000      1.000000      3.000000     39.458093      4.000000
# max    50000.000000      1.000000      3.000000     80.000000      5.000000
#
#               Parch          Fare
# count  50000.000000  50000.000000
# mean       2.493500     48.969638
# std        1.704704     35.807589
# min        0.000000      0.003933
# 25%        1.000000     20.043044
# 50%        2.000000     42.437014
# 75%        4.000000     70.797499
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age                0
# SibSp              0
# Parch              0
# Ticket             0
# Fare               0
# Cabin          34996
# Embarked           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass         Name     Sex        Age  SibSp  \
# 0            1         0       1  Passenger_1    male  28.505531      4
# 1            2         1       1  Passenger_2  female  16.290422      0
# 2            3         0       3  Passenger_3    male  54.239256      3
# 3            4         0       3  Passenger_4  female  25.934960      1
# 4            5         0       3  Passenger_5  female  44.024119      2
#
#    Parch     Ticket       Fare Cabin Embarked
# 0      1  TCKT84588  21.803954   NaN        S
# 1      3  TCKT87215  25.140471   NaN        S
# 2      4  TCKT56430  62.139033   NaN        S
# 3      2  TCKT97536  70.722917  C187        Q
# 4      3  TCKT56341  11.959749   NaN        S

# %%
data_set = df[['Pclass', 'Age', 'Cabin', 'Survived']]
data_set.head()
# Out:
#    Pclass        Age Cabin  Survived
# 0       1  28.505531   NaN         0
# 1       1  16.290422   NaN         1
# 2       3  54.239256   NaN         0
# 3       3  25.934960  C187         0
# 4       3  44.024119   NaN         0

# %%
data_set.describe()
# Out:
#              Pclass           Age      Survived
# count  50000.000000  50000.000000  50000.000000
# mean       2.299300     30.094317      0.499080
# std        0.780161     13.788365      0.500004
# min        1.000000      0.000000      0.000000
# 25%        2.000000     20.589989      0.000000
# 50%        2.000000     30.004980      0.000000
# 75%        3.000000     39.458093      1.000000
# max        3.000000     80.000000      1.000000

# %%
plt.figure(figsize=(10,5))
sns.histplot(data_set['Age'], kde=True)
plt.show()

# %%
sns.boxplot(data_set['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
# Z-score method 
upper_limit = data_set['Age'].mean() + 3*data_set['Age'].std()
lower_limit = data_set['Age'].mean() - 3*data_set['Age'].std()

print('upper_limit', upper_limit)
print('lower_limit', lower_limit)
# Out:
# upper_limit 71.45941332246035
# lower_limit -11.270779298763475

# %%
data_set.loc[(data_set['Age'] > upper_limit) | (data_set['Age'] < lower_limit)]
# Out:
#        Pclass        Age Cabin  Survived
# 556         2  72.077966   NaN         1
# 686         3  73.121616   NaN         1
# 778         3  77.591351   NaN         1
# 913         3  75.636736   NaN         1
# 1623        1  72.760810   NaN         1
# ...       ...        ...   ...       ...
# 43437       3  80.000000   NaN         0
# 44842       3  71.970264   NaN         1
# 47562       3  74.133844   NaN         1
# 48169       2  80.000000   NaN         0
# 49036       1  71.509349   NaN         0
#
# [64 rows x 4 columns]

# %%
#Triming...
new_df = data_set.loc[(data_set['Age'] < upper_limit) & (data_set['Age'] > lower_limit)]
print('old_data', len(data_set))
print('new_data', len(new_df))
sns.boxplot(new_df['Age'])
# Out:
# old_data 50000
# new_data 49936
# <Axes: ylabel='Age'>

# %%
#capping...
new_df = data_set.copy()
new_df.loc[(new_df['Age'] > upper_limit), 'Age'] = upper_limit
new_df.loc[(new_df['Age'] < lower_limit), 'Age'] = lower_limit

# %%
sns.boxplot(new_df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.histplot(new_df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
new_df.head()
# Out:
#    Pclass        Age Cabin  Survived
# 0       1  28.505531   NaN         0
# 1       1  16.290422   NaN         1
# 2       3  54.239256   NaN         0
# 3       3  25.934960  C187         0
# 4       3  44.024119   NaN         0

# %%
new_df.shape
# Out:
# (50000, 4)

# %%
from sklearn.model_selection import train_test_split

# %%
x = new_df.drop('Survived', axis=1)
y = new_df['Survived']

x_train, x_test, y_train, y_test = train_test_split(
    x, 
    y, 
    test_size=0.3, 
    random_state=1
)

x_train.size, y_train.size
# Out:
# (105000, 35000)

# %%
x_train.head()
# Out:
#        Pclass        Age Cabin
# 8950        3   6.666284   NaN
# 38421       2  50.665509   C30
# 19363       1  15.629627   NaN
# 30157       3  11.262938   NaN
# 14294       1  34.530708   NaN
