# %%
import pandas as pd;
import seaborn as sns;

# %%
data = pd.read_csv('titanic_150_rows.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 0            1         0       2           Taylor, Mrs. Anne  female  64.6
# 1            2         0       3  Cumings, Mrs. John Bradley  female  17.0
# 2            3         1       2    Bonnell, Miss. Elizabeth  female  63.0
# 3            4         0       1            Moran, Mr. James    male  40.8
# 4            5         0       3    Allen, Mr. William Henry    male  40.7
#
#    SibSp  Parch  Ticket      Fare  Cabin Embarked
# 0      3      2  T79489   28.1991    NaN        C
# 1      2      3  T18339   85.0214    NaN        C
# 2      2      1  T56920  145.3535    NaN        S
# 3      3      0  T80497  115.0878    NaN        S
# 4      1      2  T23281   99.8518    NaN        C

# %%
data.shape
# Out:
# (150, 12)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          150
# Embarked         0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  150 non-null    int64
#  1   Survived     150 non-null    int64
#  2   Pclass       150 non-null    int64
#  3   Name         150 non-null    object
#  4   Sex          150 non-null    object
#  5   Age          150 non-null    float64
#  6   SibSp        150 non-null    int64
#  7   Parch        150 non-null    int64
#  8   Ticket       150 non-null    object
#  9   Fare         150 non-null    float64
#  10  Cabin        0 non-null      float64
#  11  Embarked     150 non-null    object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 14.2+ KB

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 0            1         0       2           Taylor, Mrs. Anne  female  64.6
# 1            2         0       3  Cumings, Mrs. John Bradley  female  17.0
# 2            3         1       2    Bonnell, Miss. Elizabeth  female  63.0
# 3            4         0       1            Moran, Mr. James    male  40.8
# 4            5         0       3    Allen, Mr. William Henry    male  40.7
#
#    SibSp  Parch  Ticket      Fare  Cabin Embarked
# 0      3      2  T79489   28.1991    NaN        C
# 1      2      3  T18339   85.0214    NaN        C
# 2      2      1  T56920  145.3535    NaN        S
# 3      3      0  T80497  115.0878    NaN        S
# 4      1      2  T23281   99.8518    NaN        C

# %%
# Categorical Data..............................

# %%
sns.countplot(x='Survived', data=data)
# data['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
data['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Numerical Data...................................

# %%
# Histogram
import matplotlib.pyplot as plt
plt.hist(data['Age'])
# Out:
# (array([16., 13., 13., 10., 17., 21.,  8., 14., 18., 20.]),
#  array([ 1.  ,  7.88, 14.76, 21.64, 28.52, 35.4 , 42.28, 49.16, 56.04,
#         62.92, 69.8 ]),
#  <BarContainer object of 10 artists>)

# %%
# histplot
sns.histplot(data['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#BoxPlot
sns.boxplot(data['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
data['Age'].skew()
# Out:
# np.float64(-0.09295286707428269)
