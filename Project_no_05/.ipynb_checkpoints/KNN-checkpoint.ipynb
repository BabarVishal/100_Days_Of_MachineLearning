# %%
import pandas as pd;
import numpy as np;

# %%
df = pd.read_csv('Premier_League_Player_Statistics_2023-24_20260207_050947 (1).csv')
df.head()
# Out:
#            Player              Team    Position Position_Group  Appearances  \
# 0  Erling Haaland   Manchester City     Forward            FWD           31
# 1     Cole Palmer           Chelsea  Midfielder            MID           33
# 2  Alexander Isak  Newcastle United     Forward            FWD           30
# 3   Ollie Watkins       Aston Villa     Forward            FWD           35
# 4   Mohamed Salah         Liverpool     Forward            FWD           32
#
#    Minutes  Minutes_Per_Appearance  Goals  Assists  Goal_Contributions  ...  \
# 0     2580                      83     27        5                  32  ...
# 1     2880                      87     22       11                  33  ...
# 2     2550                      85     21        2                  23  ...
# 3     3050                      87     19       13                  32  ...
# 4     2750                      86     18       10                  28  ...
#
#    Efficiency_Rank  Performance_Category  Discipline_Category  \
# 0                1     World Class (25+)            Excellent
# 1                2     World Class (25+)                 Good
# 2                5         Elite (15-24)            Excellent
# 3                3     World Class (25+)                 Good
# 4                4     World Class (25+)            Excellent
#
#    Efficiency_Rating   Season     Competition  Country  \
# 0               2.89  2023/24  Premier League  England
# 1               2.61  2023/24  Premier League  England
# 2               2.22  2023/24  Premier League  England
# 3               2.30  2023/24  Premier League  England
# 4               2.28  2023/24  Premier League  England
#
#               League_Name  League_Level  Data_Collection_Date
# 0  English Premier League             1            2026-02-07
# 1  English Premier League             1            2026-02-07
# 2  English Premier League             1            2026-02-07
# 3  English Premier League             1            2026-02-07
# 4  English Premier League             1            2026-02-07
#
# [5 rows x 34 columns]

# %%
df.shape
# Out:
# (52, 34)

# %%
df.isnull().sum()
# Out:
# Player                       0
# Team                         0
# Position                     0
# Position_Group               0
# Appearances                  0
# Minutes                      0
# Minutes_Per_Appearance       0
# Goals                        0
# Assists                      0
# Goal_Contributions           0
# Goals_Per_90                 0
# Assists_Per_90               0
# Goal_Contributions_Per_90    0
# Minutes_Per_Goal             0
# Minutes_Per_Assist           0
# Yellow_Cards                 0
# Red_Cards                    0
# Discipline_Score             0
# Clean_Sheets                 0
# Clean_Sheet_Percentage       0
# Goals_Rank                   0
# Assists_Rank                 0
# Goal_Contributions_Rank      0
# Clean_Sheets_Rank            0
# Efficiency_Rank              0
# Performance_Category         0
# Discipline_Category          0
# Efficiency_Rating            0
# Season                       0
# Competition                  0
# Country                      0
# League_Name                  0
# League_Level                 0
# Data_Collection_Date         0
# dtype: int64

# %%
df.head()
# Out:
#            Player              Team    Position Position_Group  Appearances  \
# 0  Erling Haaland   Manchester City     Forward            FWD           31
# 1     Cole Palmer           Chelsea  Midfielder            MID           33
# 2  Alexander Isak  Newcastle United     Forward            FWD           30
# 3   Ollie Watkins       Aston Villa     Forward            FWD           35
# 4   Mohamed Salah         Liverpool     Forward            FWD           32
#
#    Minutes  Minutes_Per_Appearance  Goals  Assists  Goal_Contributions  ...  \
# 0     2580                      83     27        5                  32  ...
# 1     2880                      87     22       11                  33  ...
# 2     2550                      85     21        2                  23  ...
# 3     3050                      87     19       13                  32  ...
# 4     2750                      86     18       10                  28  ...
#
#    Efficiency_Rank  Performance_Category  Discipline_Category  \
# 0                1     World Class (25+)            Excellent
# 1                2     World Class (25+)                 Good
# 2                5         Elite (15-24)            Excellent
# 3                3     World Class (25+)                 Good
# 4                4     World Class (25+)            Excellent
#
#    Efficiency_Rating   Season     Competition  Country  \
# 0               2.89  2023/24  Premier League  England
# 1               2.61  2023/24  Premier League  England
# 2               2.22  2023/24  Premier League  England
# 3               2.30  2023/24  Premier League  England
# 4               2.28  2023/24  Premier League  England
#
#               League_Name  League_Level  Data_Collection_Date
# 0  English Premier League             1            2026-02-07
# 1  English Premier League             1            2026-02-07
# 2  English Premier League             1            2026-02-07
# 3  English Premier League             1            2026-02-07
# 4  English Premier League             1            2026-02-07
#
# [5 rows x 34 columns]

# %%
data = df[['Player', 'Team', 'Position', 'Minutes', 'Goals', 'Goal_Contributions', 'Discipline_Category', 'Efficiency_Rating']]
data.head()
# Out:
#            Player              Team    Position  Minutes  Goals  \
# 0  Erling Haaland   Manchester City     Forward     2580     27
# 1     Cole Palmer           Chelsea  Midfielder     2880     22
# 2  Alexander Isak  Newcastle United     Forward     2550     21
# 3   Ollie Watkins       Aston Villa     Forward     3050     19
# 4   Mohamed Salah         Liverpool     Forward     2750     18
#
#    Goal_Contributions Discipline_Category  Efficiency_Rating
# 0                  32           Excellent               2.89
# 1                  33                Good               2.61
# 2                  23           Excellent               2.22
# 3                  32                Good               2.30
# 4                  28           Excellent               2.28

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    data.drop('Efficiency_Rating', axis=1), 
    data['Efficiency_Rating'], 
    test_size=0.2, 
    random_state=1
)
x_train.shape, x_test.shape
# Out:
# ((41, 7), (11, 7))

# %%
x_train.head()
# Out:
#               Player         Team    Position  Minutes  Goals  \
# 3      Ollie Watkins  Aston Villa     Forward     3050     19
# 21    Alisson Becker    Liverpool  Goalkeeper     2520      0
# 48        Pedro Neto       Wolves     Forward     1380      2
# 24    Aaron Ramsdale      Arsenal  Goalkeeper      180      0
# 40  Leandro Trossard      Arsenal     Forward     1990     12
#
#     Goal_Contributions Discipline_Category
# 3                   32                Good
# 21                   1             Perfect
# 48                  11           Excellent
# 24                   0             Perfect
# 40                  14                Good

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

sc.fit(x_train)

x_train_scale = sc.transform(x_train)
x_test_scale = sc.transform(x_test)

x_train_scale
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7940\1847070680.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
#       3
# ----> 4 sc.fit(x_train)
#       5
#       6 x_train_scale = sc.transform(x_train)
#       7 x_test_scale = sc.transform(x_test)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     890             Fitted scaler.
#     891         """
#     892         # Reset internal state before fitting
#     893         self._reset()
# --> 894         return self.partial_fit(X, y, sample_weight)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     926         self : object
#     927             Fitted scaler.
#     928         """
#     929         first_call = not hasattr(self, "n_samples_seen_")
# --> 930         X = validate_data(
#     931             self,
#     932             X,
#     933             accept_sparse=("csr", "csc"),
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Ollie Watkins'
