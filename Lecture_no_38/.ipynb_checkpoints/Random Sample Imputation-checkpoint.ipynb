# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('titanic_missing_500.csv')
df.head()
# Out:
#    Survived   Age     Fare
# 0         1   6.0  20.6311
# 1         1  66.0  78.0443
# 2         1  55.0   7.1118
# 3         0  68.0      NaN
# 4         1  60.0  81.4435

# %%
df.isnull().mean() * 100
# Out:
# Survived    0.0
# Age         2.2
# Fare        2.0
# dtype: float64

# %%
x = df.drop('Survived', axis=1)
y = df['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
x_train.head()
# Out:
#       Age     Fare
# 238  23.0  96.4759
# 438  65.0  47.7097
# 475  19.0  88.6288
# 58   76.0  49.8953
# 380  59.0  49.8953

# %%
x_train['Age_imputer'] = x_train['Age']
x_test['Age_imputer'] = x_test['Age']

# %%
x_train.head()
# Out:
#       Age     Fare  Age_imputer
# 238  23.0  96.4759         23.0
# 438  65.0  47.7097         65.0
# 475  19.0  88.6288         19.0
# 58   76.0  49.8953         76.0
# 380  59.0  49.8953         59.0

# %%
x_train['Age_imputer'][x_train['Age_imputer'].isnull()] = x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
x_test['Age_imputer'][x_test['Age_imputer'].isnull()] =  x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values
# Out:
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\3848370668.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train['Age_imputer'][x_train['Age_imputer'].isnull()] = x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\3848370668.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test['Age_imputer'][x_test['Age_imputer'].isnull()] =  x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values

# %%
x_train.isnull().mean() * 100
# Out:
# Age            2.50
# Fare           2.25
# Age_imputer    0.00
# dtype: float64

# %%
x_train
# Out:
#       Age     Fare  Age_imputer
# 238  23.0  96.4759         23.0
# 438  65.0  47.7097         65.0
# 475  19.0  88.6288         19.0
# 58   76.0  49.8953         76.0
# 380  59.0  49.8953         59.0
# ..    ...      ...          ...
# 255  76.0  18.1543         76.0
# 72   65.0  87.9113         65.0
# 396  78.0  11.7827         78.0
# 235  65.0      NaN         65.0
# 37   57.0  86.8302         57.0
#
# [400 rows x 3 columns]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.kdeplot(x_train['Age'], label='Original')
sns.kdeplot(x_train['Age_imputer'], label='Imputer')
plt.legend()
plt.show()

# %%
print('Original variable variance', x_train['Age'].var())  
print('variables after random imputation', x_train['Age_imputer'].var())
# Out:
# Original variable variance 430.74183639839185
# variables after random imputation 429.63959273183013

# %%
x_train[['Fare', 'Age', 'Age_imputer']].cov()
# Out:
#                    Fare         Age  Age_imputer
# Fare         844.813585  -29.239658   -22.239391
# Age          -29.239658  430.741836   430.741836
# Age_imputer  -22.239391  430.741836   429.639593

# %%
x_train[['Age', 'Age_imputer']].boxplot()
# Out:
# <Axes: >

# %%
# sampled_value = x_train['Age'].dropna().sample(1, random_state=int(observation=['Fare']))

# %%
data = pd.read_csv('house_quality_missing.csv')
data.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN        NaN     283288
# 1          TA         Gd     177587
# 2          Ex         Po     398174
# 3          TA         Gd      94417
# 4          Fa         Ex     473391

# %%
data.isnull().mean() * 100
# Out:
# FireplaceQu    15.4
# GarageQual     14.4
# SalePrice       0.0
# dtype: float64

# %%
x = data
y = data['SalePrice']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3)

# %%
x_train['data_FireplaceQu'] = x_train['FireplaceQu']
x_test['data_FireplaceQu'] = x_test['FireplaceQu']

x_train['data_GarageQual'] = x_train['GarageQual']
x_test['data_GarageQual'] = x_test['GarageQual']

# %%
x_train['data_FireplaceQu'][x_train['data_FireplaceQu'].isnull()] = x_train['FireplaceQu'].dropna().sample(x_train['FireplaceQu'].isnull().sum()).values
x_test['data_FireplaceQu'][x_test['data_FireplaceQu'].isnull()] =  x_test['FireplaceQu'].dropna().sample(x_test['FireplaceQu'].isnull().sum()).values

x_train['data_GarageQual'][x_train['data_GarageQual'].isnull()] = x_train['GarageQual'].dropna().sample(x_train['GarageQual'].isnull().sum()).values
x_test['data_GarageQual'][x_test['data_GarageQual'].isnull()] =  x_test['GarageQual'].dropna().sample(x_test['GarageQual'].isnull().sum()).values
# Out:
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\53557308.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train['data_FireplaceQu'][x_train['data_FireplaceQu'].isnull()] = x_train['FireplaceQu'].dropna().sample(x_train['FireplaceQu'].isnull().sum()).values
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\53557308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train['data_FireplaceQu'][x_train['data_FireplaceQu'].isnull()] = x_train['FireplaceQu'].dropna().sample(x_train['FireplaceQu'].isnull().sum()).values
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\53557308.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test['data_FireplaceQu'][x_test['data_FireplaceQu'].isnull()] =  x_test['FireplaceQu'].dropna().sample(x_test['FireplaceQu'].isnull().sum()).values
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\53557308.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['data_FireplaceQu'][x_test['data_FireplaceQu'].isnull()] =  x_test['FireplaceQu'].dropna().sample(x_test['FireplaceQu'].isnull().sum()).values
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\53557308.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train['data_GarageQual'][x_train['data_GarageQual'].isnull()] = x_train['GarageQual'].dropna().sample(x_train['GarageQual'].isnull().sum()).values
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\53557308.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train['data_GarageQual'][x_train['data_GarageQual'].isnull()] = x_train['GarageQual'].dropna().sample(x_train['GarageQual'].isnull().sum()).values
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\53557308.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test['data_GarageQual'][x_test['data_GarageQual'].isnull()] =  x_test['GarageQual'].dropna().sample(x_test['GarageQual'].isnull().sum()).values
# C:\Users\91899\AppData\Local\Temp\ipykernel_6900\53557308.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['data_GarageQual'][x_test['data_GarageQual'].isnull()] =  x_test['GarageQual'].dropna().sample(x_test['GarageQual'].isnull().sum()).values

# %%
temp = pd.concat(
    [
        x_train['GarageQual'].value_counts() / len(x_train['GarageQual'].dropna()),
        x_train['data_GarageQual'].value_counts() / len(x_train)
    ],
    axis=1
)

temp.columns = ['original', 'imputer']
temp
# Out:
#     original  imputer
# TA  0.271930   0.2925
# Gd  0.207602   0.2150
# Fa  0.204678   0.1925
# Po  0.166667   0.1675
# Ex  0.149123   0.1325

# %%
temp = pd.concat(
    [
        x_train['FireplaceQu'].value_counts() / len(x_train['FireplaceQu'].dropna()),
        x_train['data_FireplaceQu'].value_counts() / len(x_train)
    ],
    axis=1
)

temp.columns = ['original', 'imputer']
temp
# Out:
#     original  imputer
# Gd  0.219653   0.2200
# Ex  0.210983   0.2025
# Po  0.196532   0.2025
# Fa  0.193642   0.1975
# TA  0.179191   0.1775
