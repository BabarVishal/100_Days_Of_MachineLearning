# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('titanic_5000_missing_age.csv')
df.head()
# Out:
#          Age  Pclass      Fare  Survived
# 0   5.939577       3   51.3938         0
# 1        NaN       3  391.5619         1
# 2  25.695244       3  495.7963         0
# 3   6.694663       1  267.9434         1
# 4   1.995994       3  342.9759         1

# %%
df.shape
# Out:
# (5000, 4)

# %%
df.isnull().sum()
# Out:
# Age         699
# Pclass        0
# Fare          0
# Survived      0
# dtype: int64

# %%
df.describe()
# Out:
#                Age       Pclass         Fare    Survived
# count  4301.000000  5000.000000  5000.000000  5000.00000
# mean     40.361166     2.403400   254.564065     0.50000
# std      22.848086     0.795987   142.619041     0.50005
# min       1.000919     1.000000     5.125000     0.00000
# 25%      20.648428     2.000000   130.887450     0.00000
# 50%      40.531691     3.000000   256.326650     0.50000
# 75%      60.655556     3.000000   378.868975     1.00000
# max      79.965059     3.000000   499.962800     1.00000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       4301 non-null   float64
#  1   Pclass    5000 non-null   int64
#  2   Fare      5000 non-null   float64
#  3   Survived  5000 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 156.4 KB

# %%
# missing Values.............................
df.isnull().sum()
# Out:
# Age         699
# Pclass        0
# Fare          0
# Survived      0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.isnull().sum()
# Out:
# Age         0
# Pclass      0
# Fare        0
# Survived    0
# dtype: int64

# %%
# Handling categorical Values.......................
df.head()
# Out:
#          Age  Pclass      Fare  Survived
# 0   5.939577       3   51.3938         0
# 1  40.531691       3  391.5619         1
# 2  25.695244       3  495.7963         0
# 3   6.694663       1  267.9434         1
# 4   1.995994       3  342.9759         1

# %%
# Outlies detection..............................
plt.figure(figsize=(17, 5))

plt.subplot(1,3,1)
sns.histplot(df['Age'], kde= True)

plt.subplot(1,3,2)
sns.histplot(df['Pclass'], kde=True)

plt.subplot(1,3,3)
sns.histplot(df['Fare'], kde=True)

plt.show()

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Pclass'])
# Out:
# <Axes: ylabel='Pclass'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
# Feature Scaling...................

# %%
df.head()
# Out:
#          Age  Pclass      Fare  Survived
# 0   5.939577       3   51.3938         0
# 1  40.531691       3  391.5619         1
# 2  25.695244       3  495.7963         0
# 3   6.694663       1  267.9434         1
# 4   1.995994       3  342.9759         1
