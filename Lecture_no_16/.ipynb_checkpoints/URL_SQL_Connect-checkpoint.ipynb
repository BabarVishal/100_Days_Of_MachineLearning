# %%
import matplotlib.pyplot as plt;
import pandas as pd;

# %%
data = pd.read_json('student_dataset.json')

# %%
data
# Out:
#                                             students
# 0  {'id': 1, 'name': 'Aarav Patil', 'age': 18, 'g...
# 1  {'id': 2, 'name': 'Riya Sharma', 'age': 17, 'g...

# %%
data2 = pd.read_json('URL')

# %% [markdown]
# Working with SQL........................................

# %%
# !pip install mysql.connector

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost', user='root', password='', database='COLLEGE')

# %%
pd.read_sql_query('select * from STUDENT', conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pd.read_sql_query('select * from STUDENT', conn)
#
# NameError: name 'conn' is not defined

# %%
# !pip install psycopg2
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.7 MB 6.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.7 MB/s eta 0:00:00
# ...

# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(
    host='localhost',
    database='college',
    user='postgres',
    password='',
    port=5432
)
df = pd.read_sql_query("SELECT * FROM student", conn)
df.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 conn = psycopg2.connect(
#       2     host='localhost',
#       3     database='college',
#       4     user='postgres',
#       5     password='VishalBabar@1234',
#       6     port=5432
#       7 )
#       8 df = pd.read_sql_query("SELECT * FROM student", conn)
#       9 df.head()
#
# File ~\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# ...
