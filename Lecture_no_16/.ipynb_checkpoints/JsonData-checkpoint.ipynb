# %%
import pandas as pd;

# %%
df = pd.read_json('random_data.json')
data = pd.json_normalize(df['data']).set_index('id')
data
# Out:
#                   name                   email  age       city    country  \
# id
# 1         Alex Johnson  alex.johnson@email.com   28   New York        USA
# 2      Maria Rodriguez   m.rodriguez@email.com   34     Madrid      Spain
# 3         Kenji Tanaka      k.tanaka@email.com   31      Tokyo      Japan
# 4         Sarah Miller       sarah.m@email.com   26    Toronto     Canada
# 5           David Chen        d.chen@email.com   42   Shanghai      China
# 6            Lisa Wang        lisa.w@email.com   29    Beijing      China
# 7         James Wilson      j.wilson@email.com   38     London         UK
# 8   Fatima Al-Mansoori    f.mansoori@email.com   27      Dubai        UAE
# 9        Michael Brown       m.brown@email.com   45    Chicago        USA
# 10       Sophie Martin      s.martin@email.com   32      Paris     France
# 11        Carlos Silva       c.silva@email.com   33  São Paulo     Brazil
# 12       Anna Kowalski    a.kowalski@email.com   30     Warsaw     Poland
# ...

# %%
data2 = pd.read_json('random_data.json')
pd.json_normalize(data2['data']).set_index('id')
# Out:
#                   name                   email  age       city    country  \
# id
# 1         Alex Johnson  alex.johnson@email.com   28   New York        USA
# 2      Maria Rodriguez   m.rodriguez@email.com   34     Madrid      Spain
# 3         Kenji Tanaka      k.tanaka@email.com   31      Tokyo      Japan
# 4         Sarah Miller       sarah.m@email.com   26    Toronto     Canada
# 5           David Chen        d.chen@email.com   42   Shanghai      China
# 6            Lisa Wang        lisa.w@email.com   29    Beijing      China
# 7         James Wilson      j.wilson@email.com   38     London         UK
# 8   Fatima Al-Mansoori    f.mansoori@email.com   27      Dubai        UAE
# 9        Michael Brown       m.brown@email.com   45    Chicago        USA
# 10       Sophie Martin      s.martin@email.com   32      Paris     France
# 11        Carlos Silva       c.silva@email.com   33  São Paulo     Brazil
# 12       Anna Kowalski    a.kowalski@email.com   30     Warsaw     Poland
# ...

# %%
df = pd.read_csv('student_placement_data.csv', index_col='Unnamed: 0')
df
# Out:
#             cgpa   iq  placement
# Unnamed: 0
# 0            6.8  123          1
# 1            5.9  106          0
# 2            5.3  121          0
# 3            7.4  132          1
# 4            5.8  142          0
# ...          ...  ...        ...
# 95           8.0  140          1
# 96           6.4  119          1
# 97           5.2   98          0
# 98           7.5  133          1
# 99           6.3  117          0
#
# [100 rows x 3 columns]
