# %%
import pandas as pd;

# %%
# !pip install psycopg2

# %%
import psycopg2

# %%
data = psycopg2.connect(
    host='localhost', 
    user='postgres',
    database='college',
    passworld='VishalBabar@1234'
)

data2 = pd.read_sql_query('select * from student', data)
data2
